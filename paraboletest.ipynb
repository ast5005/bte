# %%
3.85-2.44e-8(1850*100-1625*100)*300
# Out:
# 3.6853000000000002

# %%
using PyPlot
x=collect(-10.0:1.0:1
1.0)
y1=Array{Float64}(length(x))
y2=Array{Float64}(length(x))
for (xi,xx) in enumerate(x)
    y1[xi]=3xx*xx+2xx+5
    y2[xi]=-3xx*xx+2xx+5    
end
plot(x,y1, linestyle="None",marker=".",markersize=20,color="k")
plot(x,y2, linestyle="None",marker=".",markersize=20,color="b")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9ce28502e8>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f9ce2831e80>
