# %%
using constants
using types
using Optim
using PyPlot
using data
include("DOSfunctions.jl")
include("userfunctions.jl")
include("propertyfuncs.jl")
# Out:
# electronicProps (generic function with 1 method)

# %%
x=collect(0.0:0.1:1.0)
y1=Array{Float64}(length(x))
y2=Array{Float64}(length(x))
for (xi,xx) in enumerate(x)
    y1[xi]=vSiGe(xx)
    y2[xi]=vSiGeL(xx)
end
plot(x,y1,linestyle="-",color="c")
plot(x,y2,linestyle="-",color="b")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc6c7f9ba90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fc6b5275438>

# %%
y1
# Out:
# 11-element Array{Float64,1}:
#  5880.07
#  5442.91
#  5086.18
#  4787.74
#  4533.13
#  4312.49
#  4118.82
#  3946.97
#  3793.09
#  3654.22
#  3528.04

# %%
y2
# Out:
# 11-element Array{Float64,1}:
#  5906.16
#  5450.35
#  5079.03
#  4768.32
#  4502.82
#  4272.07
#  4068.7
#  3887.33
#  3723.92
#  3575.39
#  3439.31

# %%
1000./(y2./y1)
# Out:
# 11-element Array{Float64,1}:
#   995.581
#   998.634
#  1001.41
#  1004.07
#  1006.73
#  1009.46
#  1012.32
#  1015.34
#  1018.57
#  1022.05
#  1025.8
